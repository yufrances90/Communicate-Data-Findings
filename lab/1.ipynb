# %%
import pandas as pd
import numpy as np
import os

# %%
data_dir = '../data'

filepath = os.path.join(data_dir, 'covid_19_clean_complete.csv')

# %%
df = pd.read_csv(filepath)

# %%
df
# Out:
#       Province/State         Country/Region        Lat       Long        Date  \
# 0                NaN            Afghanistan  33.000000  65.000000  2020-01-22
# 1                NaN                Albania  41.153300  20.168300  2020-01-22
# 2                NaN                Algeria  28.033900   1.659600  2020-01-22
# 3                NaN                Andorra  42.506300   1.521800  2020-01-22
# 4                NaN                 Angola -11.202700  17.873900  2020-01-22
# ...              ...                    ...        ...        ...         ...
# 45409            NaN  Sao Tome and Principe   0.186360   6.613081  2020-07-13
# 45410            NaN                  Yemen  15.552727  48.516388  2020-07-13
# 45411            NaN                Comoros -11.645500  43.333300  2020-07-13
# 45412            NaN             Tajikistan  38.861034  71.276093  2020-07-13
# 45413            NaN                Lesotho -29.609988  28.233608  2020-07-13
#
# ...

# %%
filepath = os.path.join(data_dir, 'day_wise.csv')

df = pd.read_csv(filepath)

df
# Out:
#            Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 0    2020-01-22        555      17         28      510          0           0
# 1    2020-01-23        654      18         30      606         99           1
# 2    2020-01-24        941      26         35      880        287           8
# 3    2020-01-25       1434      42         38     1354        493          16
# 4    2020-01-26       2118      56         51     2011        684          14
# ..          ...        ...     ...        ...      ...        ...         ...
# 169  2020-07-09   12267777  554908    6638107  5074762     227038        5456
# 170  2020-07-10   12497726  560193    6776990  5160543     229949        5285
# 171  2020-07-11   12717167  565122    6901950  5250095     219441        4929
# 172  2020-07-12   12909616  569112    7013334  5327170     192449        3990
# 173  2020-07-13   13102549  573026    7153112  5376411     192933        3914
#
# ...

# %%
filepath = os.path.join(data_dir, 'country_wise_latest.csv')

df = pd.read_csv(filepath)

df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      34455    1012      21254   12189          4
# 1               Albania       3571      95       2014    1462        117
# 2               Algeria      19689    1018      14019    4652        494
# 3               Andorra        858      52        803       3          3
# 4                Angola        525      26        118     381         19
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza       6566      39       1084    5443        336
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1498     424          0    1074         33
# 185              Zambia       1895      42       1412     441          0
# 186            Zimbabwe       1034      19        343     672         49
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
filepath = os.path.join(data_dir, 'worldometer_data.csv')

df = pd.read_csv(filepath)

df
# Out:
#        Country/Region          Continent    Population  TotalCases  NewCases  \
# 0                 USA      North America  3.310711e+08     3479483       NaN
# 1              Brazil      South America  2.126118e+08     1887959       NaN
# 2               India               Asia  1.380456e+09      907645       NaN
# 3              Russia             Europe  1.459368e+08      733699       NaN
# 4                Peru      South America  3.298619e+07      330123       NaN
# ..                ...                ...           ...         ...       ...
# 204        Montserrat      North America  4.992000e+03          12       NaN
# 205      Vatican City             Europe  8.010000e+02          12       NaN
# 206  Papua New Guinea  Australia/Oceania  8.951878e+06          11       NaN
# 207    Western Sahara             Africa  5.977160e+05          10       NaN
# 208        MS Zaandam                NaN           NaN           9       NaN
#
# ...

# %%
filepath = os.path.join(data_dir, 'full_grouped.csv')

df = pd.read_csv(filepath)

df
# Out:
#              Date      Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0      2020-01-22         Afghanistan          0       0          0       0
# 1      2020-01-22             Albania          0       0          0       0
# 2      2020-01-22             Algeria          0       0          0       0
# 3      2020-01-22             Andorra          0       0          0       0
# 4      2020-01-22              Angola          0       0          0       0
# ...           ...                 ...        ...     ...        ...     ...
# 32533  2020-07-13  West Bank and Gaza       6566      39       1084    5443
# 32534  2020-07-13      Western Sahara         10       1          8       1
# 32535  2020-07-13               Yemen       1498     424          0    1074
# 32536  2020-07-13              Zambia       1895      42       1412     441
# 32537  2020-07-13            Zimbabwe       1034      19        343     672
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32538 entries, 0 to 32537
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            32538 non-null  object
#  1   Country/Region  32538 non-null  object
#  2   Confirmed       32538 non-null  int64
#  3   Deaths          32538 non-null  int64
#  4   Recovered       32538 non-null  int64
#  5   Active          32538 non-null  int64
#  6   New cases       32538 non-null  int64
#  7   New deaths      32538 non-null  int64
#  8   New recovered   32538 non-null  int64
#  9   WHO Region      32538 non-null  object
# dtypes: int64(7), object(3)
# memory usage: 2.5+ MB

# %%
df['Date']
# Out:
# 0        2020-01-22
# 1        2020-01-22
# 2        2020-01-22
# 3        2020-01-22
# 4        2020-01-22
#             ...
# 32533    2020-07-13
# 32534    2020-07-13
# 32535    2020-07-13
# 32536    2020-07-13
# 32537    2020-07-13
# Name: Date, Length: 32538, dtype: object
