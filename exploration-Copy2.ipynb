# %% [markdown]
# # Predict attrition of valuable employees
# ## by Beijia(Frances) Yu
#
# ## Preliminary Wrangling
#
# > * This is a fictional data set created by IBM data scientists.
# > * Reference: https://www.kaggle.com/pavansubhasht/ibm-hr-analytics-attrition-dataset

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %matplotlib inline

plt.rcParams['figure.figsize'] = (6, 6)

# %%
data_dir = './data'

data_filepath = os.path.join(data_dir, 'WA_Fn-UseC_-HR-Employee-Attrition.csv')

df = pd.read_csv(data_filepath)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %% [markdown]
# ### What is the structure of your dataset?
#
# > There are 1470 records in total. There are 26 numeric variables and 9 categorical variables
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# > Uncover the factors that lead to employee attrition
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# > Features can be seperated into groups
# > * age, education, education field, gender, martial status, over 18
# > * daily rate, hourly rate, monthly rate, monthly income
# > * environment satisfaction, job satisfaction, relationship satisfaction
# > * business travel, distance from home
# > * overtime, job involvement, performance rating
# > * numbwe of companies worked, total number of working years
# > * years at company, years in current role, years with current manager, years since last promotion

# %% [markdown]
# ## Univariate Exploration

# %%
gk = df.groupby('Attrition')

labels = gk.groups

patches, texts = plt.pie(gk['Attrition'].count(), colors=['k', 'c'])

plt.legend(patches, labels, loc="best")

# %% [markdown]
# > **Summary**
# > * number of people with Employee Attrition << number of people without Employee Attrition

# %% [markdown]
# ---
# ---

# %%
sns.distplot(df['Age'], color="k")

# %%
sns.distplot(df['Education'], color="k")

# %%
sns.countplot(y="EducationField", data=df, color="k")

# %%
gk = df.groupby('Gender')

labels = gk.groups

patches, texts = plt.pie(gk['Gender'].count(), colors=['k', 'c'])

plt.legend(patches, labels, loc="best")

# %%
sns.countplot(x="MaritalStatus", data=df, color="k")

# %% [markdown]
# > **Summary**
# > * Martial status, Education, Age have normal distribution
# > * Number of female >> number of male
# > * Education field has right skewed distribution

# %% [markdown]
# ---
# ---

# %%
sns.distplot(df['DailyRate'], color="k")

# %%
sns.distplot(df['HourlyRate'], color="k")

# %%
sns.distplot(df['MonthlyRate'], color="k")

# %%
sns.distplot(df['MonthlyIncome'], color="k")

# %% [markdown]
# > **Summary**
# > * Monthly rate, hourly rate and daily rate have same distribution. They all have normal distribution
# > * Monthly income has right skewed distribution. Most people earn about $2500 monthly

# %% [markdown]
# ---
# ---

# %%
sns.countplot(x="EnvironmentSatisfaction", data=df, color="k")

# %%
sns.countplot(x="JobSatisfaction", data=df, color="k")

# %%
sns.countplot(x="RelationshipSatisfaction", data=df, color="k")

# %% [markdown]
# > **Summary**
# > * Distributions are the same for all satisfaction.
# > * People are very satisfied with relationship, job and environment.

# %% [markdown]
# ---
# ---

# %%
sns.countplot(x="BusinessTravel", data=df, color="k")

# %%
sns.distplot(df['DistanceFromHome'], color="k")

# %% [markdown]
# > **Summary**
# > * Most people do not need to travel too much for work.

# %% [markdown]
# ---
# ---

# %%
gk = df.groupby('OverTime')

labels = gk.groups

patches, texts = plt.pie(gk['OverTime'].count(), colors=['k', 'c'])

plt.legend(patches, labels, loc="best")

# %%
sns.distplot(df['JobInvolvement'], color="k")

# %%
sns.countplot(x="PerformanceRating", data=df, color="k")

# %% [markdown]
# > **Summary**
# > * Number of people who work overtime << number of people who do not work overtime
# > * People are very much involved in their work, and they perform well

# %% [markdown]
# ---
# ---

# %%
sns.distplot(df['NumCompaniesWorked'], color="k")

# %%
sns.distplot(df['TotalWorkingYears'], color="k")

# %% [markdown]
# > **Summary**
# > * Number of companies worked and total number of working years have right skewed distribution.
# > * Most people work for one company.
# > * The total number of working years is between 0 - 10 for most people

# %% [markdown]
# ---
# ---

# %%
sns.distplot(df['YearsAtCompany'], color="k")

# %%
sns.distplot(df['YearsInCurrentRole'], color="k")

# %%
sns.distplot(df['YearsWithCurrManager'], color="k")

# %%
sns.distplot(df['YearsSinceLastPromotion'], color="k")

# %% [markdown]
# > **Summary**
# > * All of years at company, years in current role, year with current manager and years since last promotion has right skewed distributions
# > * The distributions of years in current role and years with current manager are almost identical.
# > * Most people just get promoted to the current position.

# %% [markdown]
# ---
# ---
# ---

# %%
df['EmployeeCount'].unique()
# Out:
# array([1])

# %%
df['EmployeeNumber'].unique()
# Out:
# array([   1,    2,    4, ..., 2064, 2065, 2068])

# %%
df['Over18'].unique()
# Out:
# array(['Y'], dtype=object)

# %% [markdown]
# > **Summary**
# > * Ignore the above columns in future analysis because
# >  * Employee count, employee number have only one value
# >  * Employee number is index of data

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# > * Several groups of features have similar distributions.
# > * Some of them have normal distributions whereas others have right skewed distribution
# > * No.
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# > Some of them are right skewed distributions. However, their skeweness clearly shows the chacteristics of the features. As a result, I did not do any modification on the data.

# %% [markdown]
# ## Bivariate Exploration

# %%
plt.rcParams['figure.figsize'] = (21, 21)

# %%
sns.catplot(x="Age", y="Attrition", data=df, color='k', kind="box")

# %%
sns.catplot(x="Education", y="Attrition", data=df, color='k', kind="box")

# %%
sns.relplot(x="EducationField", y="Attrition", data=df, color='k')

# %%
sns.relplot(x="Gender", y="Attrition", data=df, color='k')

# %% [markdown]
# > **Summary**
# > * No correlation with attrition: gender, education field, education
# > * There is a weak correlation between age and attrition
# > * Younger people(< 31) tends to have employee attrition compared to people older than 38

# %% [markdown]
# ---
# ---

# %%
sns.catplot(x="DailyRate", y="Attrition", data=df, color='k', kind="box")

# %%
sns.catplot(x="HourlyRate", y="Attrition", data=df, color='k', kind="box")

# %%
sns.catplot(x="MonthlyRate", y="Attrition", data=df, color='k', kind="box")

# %%
sns.catplot(x="MonthlyIncome", y="Attrition", data=df, color='k', kind="box")

# %% [markdown]
# > **Summary**
# > * Hourly rate and monthly rate have similar distributions
# > * Compared to the other two rates, daily rate has a slightly different distribution
# > * All of daily rate, hourly rate and montly rate have weak correlations with attrition
# > * Compared to other three rates, there is a stronger correlation between monthly income and attrition. People with lower monthly income tends to have more employee attrition

# %% [markdown]
# ---
# ---

# %%
sns.catplot(x="EnvironmentSatisfaction", y="Attrition", data=df, color='k', kind="box")

# %%
sns.catplot(x="JobSatisfaction", y="Attrition", data=df, color='k', kind="box")

# %%
sns.catplot(x="RelationshipSatisfaction", y="Attrition", data=df, color='c', kind="bar")

# %% [markdown]
# > **Summary**
# > * In univariate exploration, these three features have similar traits. However, the correlations between attrition and them are quite different
# > * No correlation between relationship satisfaction and attrition.
# > * Weak negative correlation between job satisfaction and employee attrition
# > * People who are more satisfied with the environment have less employee attrition

# %% [markdown]
# ---
# ---

# %%
sns.relplot(x="BusinessTravel", y="Attrition", data=df, color='c')

# %%
sns.catplot(y="DistanceFromHome", x="Attrition", data=df, color='c', kind="bar")

# %% [markdown]
# > **Summary**
# > * No correlation between business travel and employee attrition
# > * People who live slightly further seems to have more employee attrition

# %% [markdown]
# ---
# ---

# %%
sns.relplot(x="OverTime", y="Attrition", data=df, color='k')

# %%
sns.relplot(x="JobInvolvement", y="Attrition", data=df, color='k')

# %%
sns.relplot(x="PerformanceRating", y="Attrition", data=df, color='k')

# %% [markdown]
# > **Summary**
# > * No correlation with attrition: performance rating, job involvement and overtime

# %% [markdown]
# ---
# ---

# %%
sns.catplot(x="NumCompaniesWorked", y="Attrition", data=df, color='k', kind="box")

# %%
sns.catplot(x="TotalWorkingYears", y="Attrition", data=df, color='k', kind="box")

# %% [markdown]
# > **Summary**
# > * People who work for more companies tends to feel more employee attrition
# > * People who work for more years tends to feel less employee attrition

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# > There are several features having no correlation with employee attrition
# > In univariate exploration, environment satisfaction, job satisfaction and relationship satisfaction have similar distributions. However, the correlation between attrition and them are quite different.
# > Some features have positive correlations but others have negative relations.
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > Most categorical variables does not have correlation with employee attrition

# %% [markdown]
# ## Multivariate Exploration

# %%
palette = sns.set_palette("Greys")

# %%
sns.catplot(
    y="Age", 
    x="Education", 
    data=df, 
    height=7, 
    aspect=2,
    hue='Attrition', 
    palette=palette, 
    kind="boxen")

# %% [markdown]
# > * By comparing median values
# >   * The younger the people, the more with employee attrition
# >   * No correlation between education level and employee attrition(Attrition = Yes)
# >   * The higher the education level, the less with employee attrition(Attrition = No)
# >
# >
# > * The higher the education level, the less with employee attrition
# > * The older a person is, the less with employee attrition

# %%
sns.catplot(
    x="EducationField", 
    y="Education", 
    data=df, 
    height=7, 
    aspect=2,
    hue='Attrition', 
    palette=palette, 
    kind="boxen")

# %% [markdown]
# > * By comparing median values
# >   * except for other education field, education field and education level do not have correlation with employee attrition
# > * People with master degree in life sciences, medical, marketing as well as other have less employee attrition. On the other hand, people with master degree in technical degree and human resources have more employee attrition

# %%
sns.catplot(
    x="Gender", 
    y="Education", 
    data=df, 
    height=7, 
    aspect=2,
    hue='Attrition', 
    palette=palette, 
    kind="boxen")

# %% [markdown]
# > * By comparing median values
# >  * no correlation between gender as well as education level and employee attrition

# %%
sns.catplot(
    x="MaritalStatus", 
    y="Education", 
    data=df, 
    height=7, 
    aspect=2,
    hue='Attrition', 
    palette=palette, 
    kind="boxen")

# %% [markdown]
# > * By comparing median values
# >   * No correlation between marital status as well as education level and employee attrition

# %% [markdown]
# ---
# ---

# %%
sns.catplot(
    x="BusinessTravel", 
    y="MonthlyIncome", 
    data=df, 
    height=7, 
    aspect=2,
    hue='Attrition', 
    palette=palette, 
    order=["Non-Travel", "Travel_Rarely", "Travel_Frequently"], 
    kind="boxen")

# %% [markdown]
# > * By comparing median values
# >  * No correlation between the frequency of business travel and employee attrition
# >  * the more the monthly income, the less with employee attrition

# %% [markdown]
# ---
# ---

# %%
sns.catplot(
    x="EnvironmentSatisfaction", 
    y="RelationshipSatisfaction", 
    data=df, 
    height=7, 
    aspect=2,
    hue='Attrition', 
    palette=palette, 
    kind="boxen")

# %% [markdown]
# > * By comparing median values
# >   * There is no correlation between environment satisfaction as well as relationship satisfaction and employee attrition

# %%
sns.catplot(
    x="JobSatisfaction", 
    y="RelationshipSatisfaction", 
    data=df, 
    height=7, 
    aspect=2,
    hue='Attrition', 
    palette=palette, 
    kind="boxen")

# %% [markdown]
# > * By comparing median values
# >   * except for people with medium job satisfaction, there is no correlation between job satisfaction as well as relationship satisfaction and employee attrition

# %%
sns.catplot(
    x="EnvironmentSatisfaction", 
    y="RelationshipSatisfaction", 
    data=df, 
    height=7, 
    aspect=2,
    hue='Attrition', 
    palette=palette, 
    kind="boxen")

# %% [markdown]
# > * By comparing median values, there is no correlation between environment satisfaction as well as relationship satisfaction and employee attrition

# %% [markdown]
# ---
# ---

# %%
sns.catplot(
    y="DistanceFromHome", 
    x="BusinessTravel", 
    data=df, 
    height=7, 
    aspect=2,
    hue='Attrition', 
    palette=palette, 
    order=["Non-Travel", "Travel_Rarely", "Travel_Frequently"], 
    kind="boxen")

# %% [markdown]
# > * By comparing median values
# >   * The further away the company from home, the more employee attrition
# > * No correlation between the frequency of business travel and employee attrition
# > * By comparing distributions with Attrition = Yes, for people who live very closed to company
# >   * The more frequent business travel, the more with employee attrition

# %% [markdown]
# ---
# ---

# %%
sns.catplot(
    y="JobInvolvement", 
    x="PerformanceRating",  
    data=df, 
    height=6, 
    aspect=2,
    hue='Attrition', 
    palette=palette, 
    kind="boxen")

# %% [markdown]
# > * By comparing the distributions of majority
# >   * No correlation between performance rating as well as job involvement and employee attrition
# > * By comparing distributions with Attrition = Yes, for people having at least high involvement, the higher the performance rating, the less with employee attrition

# %% [markdown]
# ---
# ---

# %%
sns.catplot(
    x="NumCompaniesWorked", 
    y="TotalWorkingYears", 
    data=df, 
    height=7,
    aspect=2,
    hue='Attrition', 
    palette=palette, 
    kind="boxen")

# %% [markdown]
# > * By comparing median values
# >   * The longer a person has worked, the less with employee attrition
# >   * No correlation between the number of companies worked and employee attrition

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > Your answer here!
#
# ### Were there any interesting or surprising interactions between features?
#
# > Your answer here!

# %% [markdown]
# > At the end of your report, make sure that you export the notebook as an
# html file from the `File > Download as... > HTML` menu. Make sure you keep
# track of where the exported file goes, so you can put it in the same folder
# as this notebook for project submission. Also, make sure you remove all of
# the quote-formatted guide notes like this one before you finish your report!
