# %% [markdown]
# # (Dataset Exploration Title)
# ## by (your name here)
#
# ## Preliminary Wrangling
#
# > Briefly introduce your dataset here.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %matplotlib inline

# %%
data_dir = './data'

# %%
filepath = os.path.join(data_dir, 'winequality-red.csv')

df = pd.read_csv(filepath)

# %%
sns.pairplot(df, dropna=True, kind='reg', corner=True)

# %%
df['quality'] = df['quality'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   object
# dtypes: float64(11), object(1)
# memory usage: 150.0+ KB

# %% [markdown]
# ### What is the structure of your dataset?
#
# > Your answer here!
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# > Your answer here!
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# > Your answer here!

# %% [markdown]
# ## Univariate Exploration

# %%
plt.hist(df['pH'], color='c')
# Out:
# (array([  2.,  27., 134., 361., 555., 352., 132.,  29.,   3.,   4.]),
#  array([2.74 , 2.867, 2.994, 3.121, 3.248, 3.375, 3.502, 3.629, 3.756,
#         3.883, 4.01 ]),
#  <a list of 10 Patch objects>)

# %%
df['alcohol'].describe()
# Out:
# count    1599.000000
# mean       10.422983
# std         1.065668
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
bins = np.arange(8, df['alcohol'].max()+0.5, 0.5)

plt.hist(df['alcohol'], bins=bins, color='c')
# Out:
# (array([  2.,   5., 290., 383., 236., 216., 187., 118.,  71.,  62.,  15.,
#           6.,   7.,   1.]),
#  array([ 8. ,  8.5,  9. ,  9.5, 10. , 10.5, 11. , 11.5, 12. , 12.5, 13. ,
#         13.5, 14. , 14.5, 15. ]),
#  <a list of 14 Patch objects>)

# %%
sns.countplot(x="quality", data=df, color='c')

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# > Your answer here!
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# > Your answer here!

# %% [markdown]
# ## Bivariate Exploration
#
# > In this section, investigate relationships between pairs of variables in your
# data. Make sure the variables that you cover here have been introduced in some
# fashion in the previous section (univariate exploration).

# %%
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]

# %%
palette = sns.color_palette(flatui)

# %%
sns.catplot(x="quality", y="pH", kind="boxen", data=df, color='c')

# %%
sns.catplot(x="quality", y="alcohol", kind="boxen", data=df, color='c')

# %%
sns.catplot(x="quality", y="density", kind="boxen", data=df, color='c')

# %%
x = df['alcohol']
y = df['quality'].astype(int)

x.describe(), y.describe()
# Out:
# (count    1599.000000
#  mean       10.422983
#  std         1.065668
#  min         8.400000
#  25%         9.500000
#  50%        10.200000
#  75%        11.100000
#  max        14.900000
#  Name: alcohol, dtype: float64,
#  count    1599.000000
#  mean        5.636023
#  std         0.807569
#  min         3.000000
#  25%         5.000000
#  50%         6.000000
#  75%         6.000000
#  max         8.000000
#  Name: quality, dtype: float64)

# %%
bins_x = np.arange(8.4, 14.9+0.1, 0.1)
bins_y = np.arange(3, 8+1, 1)

plt.hist2d(x=x, y=y,cmap='coolwarm', bins=[bins_x, bins_y])
plt.colorbar()

# %%
sns.catplot(x='alcohol', y='quality', data=df, kind='violin', height=7, aspect=2)

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# > Your answer here!
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > Your answer here!

# %% [markdown]
# ## Multivariate Exploration
#
# > Create plots of three or more variables to investigate your data even
# further. Make sure that your investigations are justified, and follow from
# your work in the previous sections.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > Your answer here!
#
# ### Were there any interesting or surprising interactions between features?
#
# > Your answer here!

# %% [markdown]
# > At the end of your report, make sure that you export the notebook as an
# html file from the `File > Download as... > HTML` menu. Make sure you keep
# track of where the exported file goes, so you can put it in the same folder
# as this notebook for project submission. Also, make sure you remove all of
# the quote-formatted guide notes like this one before you finish your report!
