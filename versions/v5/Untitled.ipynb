# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %matplotlib inline

# %%
data_dir = './data'

# %%
bs_filepath = os.path.join(data_dir, 'austin_bikeshare_stations.csv')
bt_filepath = os.path.join(data_dir, 'austin_bikeshare_trips.csv')
bw_filepath = os.path.join(data_dir, 'austin_weather.csv')

# %%
station_df = pd.read_csv(bs_filepath)
trip_df = pd.read_csv(bt_filepath)
weather_df = pd.read_csv(bw_filepath)

# %%
station_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   latitude    72 non-null     float64
#  1   location    72 non-null     object
#  2   longitude   72 non-null     float64
#  3   name        72 non-null     object
#  4   station_id  72 non-null     int64
#  5   status      72 non-null     object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 3.5+ KB

# %%
trip_df.head()
# Out:
#    bikeid checkout_time  duration_minutes  end_station_id  \
# 0     8.0      19:12:00                41          2565.0
# 1   141.0       2:06:04                 6          2570.0
# 2   578.0      16:28:27                13          2498.0
# 3   555.0      15:12:00                80          2712.0
# 4    86.0      15:39:13                25          3377.0
#
#                            end_station_name  month  start_station_id  \
# 0                      Trinity & 6th Street    3.0            2536.0
# 1                  South Congress & Academy   10.0            2494.0
# 2   Convention Center / 4th St. @ MetroRail    3.0            2538.0
# 3                   Toomey Rd @ South Lamar   11.0            2497.0
# 4  MoPac Pedestrian Bridge @ Veterans Drive    4.0            2707.0
#
#                   start_station_name           start_time  \
# 0                   Waller & 6th St.  2015-03-19 19:12:00
# 1                     2nd & Congress  2016-10-30 02:06:04
# 2    Bullock Museum @ Congress & MLK  2016-03-11 16:28:27
# 3  Capitol Station / Congress & 11th  2014-11-23 15:12:00
# 4               Rainey St @ Cummings  2017-04-16 15:39:13
#
#                   subscriber_type     trip_id    year
# 0                         Walk Up  9900082882  2015.0
# 1                        Local365    12617682  2016.0
# 2                        Local365     9075366  2016.0
# 3  24-Hour Kiosk (Austin B-cycle)  9900319298  2014.0
# 4                         Walk Up    14468597  2017.0

# %%
weather_df.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
#   SeaLevelPressureAvgInches SeaLevelPressureLowInches VisibilityHighMiles  \
# 0                     29.68                     29.59                  10
# 1                     30.13                     29.87                  10
# 2                     30.49                     30.41                  10
# 3                     30.45                      30.3                  10
# 4                     30.33                     30.27                  10
#
#   VisibilityAvgMiles VisibilityLowMiles WindHighMPH WindAvgMPH WindGustMPH  \
# 0                  7                  2          20          4          31
# 1                 10                  5          16          6          25
# 2                 10                 10           8          3          12
# 3                 10                  7          12          4          20
# 4                 10                  7          10          2          16
#
#   PrecipitationSumInches               Events
# 0                   0.46  Rain , Thunderstorm
# 1                      0
# 2                      0
# 3                      0
# 4                      T
#
# [5 rows x 21 columns]

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        1319 non-null   object
#  1   TempHighF                   1319 non-null   int64
#  2   TempAvgF                    1319 non-null   int64
#  3   TempLowF                    1319 non-null   int64
#  4   DewPointHighF               1319 non-null   object
#  5   DewPointAvgF                1319 non-null   object
#  6   DewPointLowF                1319 non-null   object
#  7   HumidityHighPercent         1319 non-null   object
#  8   HumidityAvgPercent          1319 non-null   object
#  9   HumidityLowPercent          1319 non-null   object
#  10  SeaLevelPressureHighInches  1319 non-null   object
#  11  SeaLevelPressureAvgInches   1319 non-null   object
#  12  SeaLevelPressureLowInches   1319 non-null   object
#  13  VisibilityHighMiles         1319 non-null   object
#  14  VisibilityAvgMiles          1319 non-null   object
#  15  VisibilityLowMiles          1319 non-null   object
#  16  WindHighMPH                 1319 non-null   object
#  17  WindAvgMPH                  1319 non-null   object
#  18  WindGustMPH                 1319 non-null   object
#  19  PrecipitationSumInches      1319 non-null   object
#  20  Events                      1319 non-null   object
# dtypes: int64(3), object(18)
# memory usage: 216.5+ KB

# %%
weather_df['Date'].unique().size
# Out:
# 1319

# %% [markdown]
# ---
# ---

# %%
trip_df_clean = trip_df.copy()

# %% [markdown]
# ---

# %%
trip_df_clean.dropna(inplace=True, axis=0)

# %%
trip_df_clean['Date'] = trip_df_clean['start_time'].str.split().str[0]
trip_df_clean['start_time'] = trip_df_clean['start_time'].str.split().str[1]

# %%
rows_to_remove = trip_df_clean.query('year == "nan"').index

trip_df_clean.drop(rows_to_remove, inplace=True)

# %%
trip_df_clean['year'] = pd.to_numeric(trip_df_clean['year'], downcast='integer')
trip_df_clean['month'] = pd.to_numeric(trip_df_clean['month'], downcast='integer')

# %%
trip_df_clean['start_station_id'] = pd.to_numeric(trip_df_clean['start_station_id'], downcast='integer')
trip_df_clean['end_station_id'] = pd.to_numeric(trip_df_clean['end_station_id'], downcast='integer')

# %%
trip_df_clean
# Out:
#         bikeid checkout_time  duration_minutes  end_station_id  \
# 0          8.0      19:12:00                41            2565
# 1        141.0       2:06:04                 6            2570
# 2        578.0      16:28:27                13            2498
# 3        555.0      15:12:00                80            2712
# 4         86.0      15:39:13                25            3377
# ...        ...           ...               ...             ...
# 649226    52.0       0:12:00                90            2571
# 649227   104.0      17:20:44                53            2499
# 649228   240.0      13:12:55                44            2495
# 649229   421.0      14:45:34               106            2494
# 649230   206.0      13:12:31                28            2546
#
#                                 end_station_name  month  start_station_id  \
# 0                           Trinity & 6th Street      3              2536
# 1                       South Congress & Academy     10              2494
# 2        Convention Center / 4th St. @ MetroRail      3              2538
# 3                        Toomey Rd @ South Lamar     11              2497
# 4       MoPac Pedestrian Bridge @ Veterans Drive      4              2707
# ...                                          ...    ...               ...
# 649226                    Red River & 8th Street      7              2544
# 649227                  City Hall / Lavaca & 2nd      2              3619
# 649228                            4th & Congress     11              2495
# 649229                            2nd & Congress      5              2494
# 649230                  ACC - West & 12th Street     12              2546
#
#                        start_station_name start_time  \
# 0                        Waller & 6th St.   19:12:00
# 1                          2nd & Congress   02:06:04
# 2         Bullock Museum @ Congress & MLK   16:28:27
# 3       Capitol Station / Congress & 11th   15:12:00
# 4                    Rainey St @ Cummings   15:39:13
# ...                                   ...        ...
# 649226          East 6th & Pedernales St.   00:12:00
# 649227                     6th & Congress   17:20:44
# 649228                     4th & Congress   13:12:55
# 649229                     2nd & Congress   14:45:34
# 649230           ACC - West & 12th Street   13:12:31
#
#                        subscriber_type     trip_id  year        Date
# 0                              Walk Up  9900082882  2015  2015-03-19
# 1                             Local365    12617682  2016  2016-10-30
# 2                             Local365     9075366  2016  2016-03-11
# 3       24-Hour Kiosk (Austin B-cycle)  9900319298  2014  2014-11-23
# 4                              Walk Up    14468597  2017  2017-04-16
# ...                                ...         ...   ...         ...
# 649226  24-Hour Kiosk (Austin B-cycle)  9900185926  2014  2014-07-06
# 649227                         Walk Up    13649794  2017  2017-02-06
# 649228                         Walk Up  9900329990  2015  2015-11-18
# 649229      Try Before You Buy Special    10219003  2016  2016-05-29
# 649230                        Local365  9900345497  2015  2015-12-08
#
# [581625 rows x 13 columns]

# %%
trip_df_clean[['start_station_id', 'end_station_id']]
# Out:
#         start_station_id  end_station_id
# 0                   2536            2565
# 1                   2494            2570
# 2                   2538            2498
# 3                   2497            2712
# 4                   2707            3377
# ...                  ...             ...
# 649226              2544            2571
# 649227              3619            2499
# 649228              2495            2495
# 649229              2494            2494
# 649230              2546            2546
#
# [581625 rows x 2 columns]

# %%
df_final = trip_df_clean.copy()

# %%
df_final = df_final.merge(weather_df, on='Date')

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 581625 entries, 0 to 581624
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   bikeid                      581625 non-null  float64
#  1   checkout_time               581625 non-null  object
#  2   duration_minutes            581625 non-null  int64
#  3   end_station_id              581625 non-null  int16
#  4   end_station_name            581625 non-null  object
#  5   month                       581625 non-null  int8
#  6   start_station_id            581625 non-null  int16
#  7   start_station_name          581625 non-null  object
#  8   start_time                  581625 non-null  object
#  9   subscriber_type             581625 non-null  object
#  10  trip_id                     581625 non-null  int64
#  11  year                        581625 non-null  int16
#  12  Date                        581625 non-null  object
#  13  TempHighF                   581625 non-null  int64
#  14  TempAvgF                    581625 non-null  int64
#  15  TempLowF                    581625 non-null  int64
#  16  DewPointHighF               581625 non-null  object
#  17  DewPointAvgF                581625 non-null  object
#  18  DewPointLowF                581625 non-null  object
#  19  HumidityHighPercent         581625 non-null  object
#  20  HumidityAvgPercent          581625 non-null  object
#  21  HumidityLowPercent          581625 non-null  object
#  22  SeaLevelPressureHighInches  581625 non-null  object
#  23  SeaLevelPressureAvgInches   581625 non-null  object
#  24  SeaLevelPressureLowInches   581625 non-null  object
#  25  VisibilityHighMiles         581625 non-null  object
#  26  VisibilityAvgMiles          581625 non-null  object
#  27  VisibilityLowMiles          581625 non-null  object
#  28  WindHighMPH                 581625 non-null  object
#  29  WindAvgMPH                  581625 non-null  object
#  30  WindGustMPH                 581625 non-null  object
#  31  PrecipitationSumInches      581625 non-null  object
#  32  Events                      581625 non-null  object
# dtypes: float64(1), int16(3), int64(5), int8(1), object(23)
# memory usage: 137.0+ MB

# %%
trip_df_clean
# Out:
#         bikeid checkout_time  duration_minutes  end_station_id  \
# 0          8.0      19:12:00                41            2565
# 1        141.0       2:06:04                 6            2570
# 2        578.0      16:28:27                13            2498
# 3        555.0      15:12:00                80            2712
# 4         86.0      15:39:13                25            3377
# ...        ...           ...               ...             ...
# 649226    52.0       0:12:00                90            2571
# 649227   104.0      17:20:44                53            2499
# 649228   240.0      13:12:55                44            2495
# 649229   421.0      14:45:34               106            2494
# 649230   206.0      13:12:31                28            2546
#
#                                 end_station_name  month  start_station_id  \
# 0                           Trinity & 6th Street      3              2536
# 1                       South Congress & Academy     10              2494
# 2        Convention Center / 4th St. @ MetroRail      3              2538
# 3                        Toomey Rd @ South Lamar     11              2497
# 4       MoPac Pedestrian Bridge @ Veterans Drive      4              2707
# ...                                          ...    ...               ...
# 649226                    Red River & 8th Street      7              2544
# 649227                  City Hall / Lavaca & 2nd      2              3619
# 649228                            4th & Congress     11              2495
# 649229                            2nd & Congress      5              2494
# 649230                  ACC - West & 12th Street     12              2546
#
#                        start_station_name start_time  \
# 0                        Waller & 6th St.   19:12:00
# 1                          2nd & Congress   02:06:04
# 2         Bullock Museum @ Congress & MLK   16:28:27
# 3       Capitol Station / Congress & 11th   15:12:00
# 4                    Rainey St @ Cummings   15:39:13
# ...                                   ...        ...
# 649226          East 6th & Pedernales St.   00:12:00
# 649227                     6th & Congress   17:20:44
# 649228                     4th & Congress   13:12:55
# 649229                     2nd & Congress   14:45:34
# 649230           ACC - West & 12th Street   13:12:31
#
#                        subscriber_type     trip_id  year        Date
# 0                              Walk Up  9900082882  2015  2015-03-19
# 1                             Local365    12617682  2016  2016-10-30
# 2                             Local365     9075366  2016  2016-03-11
# 3       24-Hour Kiosk (Austin B-cycle)  9900319298  2014  2014-11-23
# 4                              Walk Up    14468597  2017  2017-04-16
# ...                                ...         ...   ...         ...
# 649226  24-Hour Kiosk (Austin B-cycle)  9900185926  2014  2014-07-06
# 649227                         Walk Up    13649794  2017  2017-02-06
# 649228                         Walk Up  9900329990  2015  2015-11-18
# 649229      Try Before You Buy Special    10219003  2016  2016-05-29
# 649230                        Local365  9900345497  2015  2015-12-08
#
# [581625 rows x 13 columns]

# %%
df_final[10000:10010].T
# Out:
#                                            10000                     10001  \
# bikeid                                       861                       576
# checkout_time                           14:48:56                  14:34:01
# duration_minutes                              15                        16
# end_station_id                              2494                      2494
# end_station_name                  2nd & Congress            2nd & Congress
# month                                          9                         9
# start_station_id                            2575                      2548
# start_station_name          Riverside @ S. Lamar  UT West Mall @ Guadalupe
# start_time                              14:48:56                  14:34:01
# subscriber_type                         Explorer                  Local365
# trip_id                                 11737411                  11737072
# year                                        2016                      2016
# Date                                  2016-09-03                2016-09-03
# TempHighF                                     92                        92
# TempAvgF                                      83                        83
# TempLowF                                      73                        73
# DewPointHighF                                 74                        74
# DewPointAvgF                                  72                        72
# DewPointLowF                                  69                        69
# HumidityHighPercent                           94                        94
# HumidityAvgPercent                            73                        73
# HumidityLowPercent                            52                        52
# SeaLevelPressureHighInches                 29.99                     29.99
# SeaLevelPressureAvgInches                  29.95                     29.95
# SeaLevelPressureLowInches                   29.9                      29.9
# VisibilityHighMiles                           10                        10
# VisibilityAvgMiles                             9                         9
# VisibilityLowMiles                             5                         5
# WindHighMPH                                   10                        10
# WindAvgMPH                                     3                         3
# WindGustMPH                                   17                        17
# PrecipitationSumInches                         T                         T
# Events
#
#                                        10002  \
# bikeid                                   282
# checkout_time                       11:22:57
# duration_minutes                          10
# end_station_id                          2494
# end_station_name              2nd & Congress
# month                                      9
# start_station_id                        2564
# start_station_name          5th & San Marcos
# start_time                          11:22:57
# subscriber_type                      Local30
# trip_id                             11732946
# year                                    2016
# Date                              2016-09-03
# TempHighF                                 92
# TempAvgF                                  83
# TempLowF                                  73
# DewPointHighF                             74
# DewPointAvgF                              72
# DewPointLowF                              69
# HumidityHighPercent                       94
# HumidityAvgPercent                        73
# HumidityLowPercent                        52
# SeaLevelPressureHighInches             29.99
# SeaLevelPressureAvgInches              29.95
# SeaLevelPressureLowInches               29.9
# VisibilityHighMiles                       10
# VisibilityAvgMiles                         9
# VisibilityLowMiles                         5
# WindHighMPH                               10
# WindAvgMPH                                 3
# WindGustMPH                               17
# PrecipitationSumInches                     T
# Events
#
#                                                           10003  \
# bikeid                                                      334
# checkout_time                                          14:33:28
# duration_minutes                                            135
# end_station_id                                             2549
# end_station_name            Long Center @ South 1st & Riverside
# month                                                         9
# start_station_id                                           2549
# start_station_name          Long Center @ South 1st & Riverside
# start_time                                             14:33:28
# subscriber_type                                         Walk Up
# trip_id                                                11737061
# year                                                       2016
# Date                                                 2016-09-03
# TempHighF                                                    92
# TempAvgF                                                     83
# TempLowF                                                     73
# DewPointHighF                                                74
# DewPointAvgF                                                 72
# DewPointLowF                                                 69
# HumidityHighPercent                                          94
# HumidityAvgPercent                                           73
# HumidityLowPercent                                           52
# SeaLevelPressureHighInches                                29.99
# SeaLevelPressureAvgInches                                 29.95
# SeaLevelPressureLowInches                                  29.9
# VisibilityHighMiles                                          10
# VisibilityAvgMiles                                            9
# VisibilityLowMiles                                            5
# WindHighMPH                                                  10
# WindAvgMPH                                                    3
# WindGustMPH                                                  17
# PrecipitationSumInches                                        T
# Events
#
#                                                                10004  \
# bikeid                                                           133
# checkout_time                                               11:18:50
# duration_minutes                                                  32
# end_station_id                                                  3377
# end_station_name            MoPac Pedestrian Bridge @ Veterans Drive
# month                                                              9
# start_station_id                                                3377
# start_station_name          MoPac Pedestrian Bridge @ Veterans Drive
# start_time                                                  11:18:50
# subscriber_type                           Try Before You Buy Special
# trip_id                                                     11732867
# year                                                            2016
# Date                                                      2016-09-03
# TempHighF                                                         92
# TempAvgF                                                          83
# TempLowF                                                          73
# DewPointHighF                                                     74
# DewPointAvgF                                                      72
# DewPointLowF                                                      69
# HumidityHighPercent                                               94
# HumidityAvgPercent                                                73
# HumidityLowPercent                                                52
# SeaLevelPressureHighInches                                     29.99
# SeaLevelPressureAvgInches                                      29.95
# SeaLevelPressureLowInches                                       29.9
# VisibilityHighMiles                                               10
# VisibilityAvgMiles                                                 9
# VisibilityLowMiles                                                 5
# WindHighMPH                                                       10
# WindAvgMPH                                                         3
# WindGustMPH                                                       17
# PrecipitationSumInches                                             T
# Events
#
#                                                  10005  \
# bikeid                                             236
# checkout_time                                 16:24:47
# duration_minutes                                    15
# end_station_id                                    2504
# end_station_name            South Congress & Elizabeth
# month                                                9
# start_station_id                                  2494
# start_station_name                      2nd & Congress
# start_time                                    16:24:47
# subscriber_type                               Explorer
# trip_id                                       11739512
# year                                              2016
# Date                                        2016-09-03
# TempHighF                                           92
# TempAvgF                                            83
# TempLowF                                            73
# DewPointHighF                                       74
# DewPointAvgF                                        72
# DewPointLowF                                        69
# HumidityHighPercent                                 94
# HumidityAvgPercent                                  73
# HumidityLowPercent                                  52
# SeaLevelPressureHighInches                       29.99
# SeaLevelPressureAvgInches                        29.95
# SeaLevelPressureLowInches                         29.9
# VisibilityHighMiles                                 10
# VisibilityAvgMiles                                   9
# VisibilityLowMiles                                   5
# WindHighMPH                                         10
# WindAvgMPH                                           3
# WindGustMPH                                         17
# PrecipitationSumInches                               T
# Events
#
#                                                  10006  \
# bikeid                                             241
# checkout_time                                 14:23:17
# duration_minutes                                    11
# end_station_id                                    2502
# end_station_name            Barton Springs & Riverside
# month                                                9
# start_station_id                                  2537
# start_station_name                      West & 6th St.
# start_time                                    14:23:17
# subscriber_type                                Walk Up
# trip_id                                       11736836
# year                                              2016
# Date                                        2016-09-03
# TempHighF                                           92
# TempAvgF                                            83
# TempLowF                                            73
# DewPointHighF                                       74
# DewPointAvgF                                        72
# DewPointLowF                                        69
# HumidityHighPercent                                 94
# HumidityAvgPercent                                  73
# HumidityLowPercent                                  52
# SeaLevelPressureHighInches                       29.99
# SeaLevelPressureAvgInches                        29.95
# SeaLevelPressureLowInches                         29.9
# VisibilityHighMiles                                 10
# VisibilityAvgMiles                                   9
# VisibilityLowMiles                                   5
# WindHighMPH                                         10
# WindAvgMPH                                           3
# WindGustMPH                                         17
# PrecipitationSumInches                               T
# Events
#
#                                                               10007  \
# bikeid                                                          414
# checkout_time                                              10:22:02
# duration_minutes                                                 10
# end_station_id                                                 2564
# end_station_name                                   5th & San Marcos
# month                                                             9
# start_station_id                                               2823
# start_station_name          Capital Metro HQ - East 5th at Broadway
# start_time                                                 10:22:02
# subscriber_type                                             Local30
# trip_id                                                    11731867
# year                                                           2016
# Date                                                     2016-09-03
# TempHighF                                                        92
# TempAvgF                                                         83
# TempLowF                                                         73
# DewPointHighF                                                    74
# DewPointAvgF                                                     72
# DewPointLowF                                                     69
# HumidityHighPercent                                              94
# HumidityAvgPercent                                               73
# HumidityLowPercent                                               52
# SeaLevelPressureHighInches                                    29.99
# SeaLevelPressureAvgInches                                     29.95
# SeaLevelPressureLowInches                                      29.9
# VisibilityHighMiles                                              10
# VisibilityAvgMiles                                                9
# VisibilityLowMiles                                                5
# WindHighMPH                                                      10
# WindAvgMPH                                                        3
# WindGustMPH                                                      17
# PrecipitationSumInches                                            T
# Events
#
#                                                                10008  \
# bikeid                                                           191
# checkout_time                                               14:50:10
# duration_minutes                                                  32
# end_station_id                                                  3377
# end_station_name            MoPac Pedestrian Bridge @ Veterans Drive
# month                                                              9
# start_station_id                                                2707
# start_station_name                              Rainey St @ Cummings
# start_time                                                  14:50:10
# subscriber_type                                              Walk Up
# trip_id                                                     11737431
# year                                                            2016
# Date                                                      2016-09-03
# TempHighF                                                         92
# TempAvgF                                                          83
# TempLowF                                                          73
# DewPointHighF                                                     74
# DewPointAvgF                                                      72
# DewPointLowF                                                      69
# HumidityHighPercent                                               94
# HumidityAvgPercent                                                73
# HumidityLowPercent                                                52
# SeaLevelPressureHighInches                                     29.99
# SeaLevelPressureAvgInches                                      29.95
# SeaLevelPressureLowInches                                       29.9
# VisibilityHighMiles                                               10
# VisibilityAvgMiles                                                 9
# VisibilityLowMiles                                                 5
# WindHighMPH                                                       10
# WindAvgMPH                                                         3
# WindGustMPH                                                       17
# PrecipitationSumInches                                             T
# Events
#
#                                                           10009
# bikeid                                                      709
# checkout_time                                          14:31:49
# duration_minutes                                            137
# end_station_id                                             2549
# end_station_name            Long Center @ South 1st & Riverside
# month                                                         9
# start_station_id                                           2549
# start_station_name          Long Center @ South 1st & Riverside
# start_time                                             14:31:49
# subscriber_type                                         Walk Up
# trip_id                                                11737028
# year                                                       2016
# Date                                                 2016-09-03
# TempHighF                                                    92
# TempAvgF                                                     83
# TempLowF                                                     73
# DewPointHighF                                                74
# DewPointAvgF                                                 72
# DewPointLowF                                                 69
# HumidityHighPercent                                          94
# HumidityAvgPercent                                           73
# HumidityLowPercent                                           52
# SeaLevelPressureHighInches                                29.99
# SeaLevelPressureAvgInches                                 29.95
# SeaLevelPressureLowInches                                  29.9
# VisibilityHighMiles                                          10
# VisibilityAvgMiles                                            9
# VisibilityLowMiles                                            5
# WindHighMPH                                                  10
# WindAvgMPH                                                    3
# WindGustMPH                                                  17
# PrecipitationSumInches                                        T
# Events
