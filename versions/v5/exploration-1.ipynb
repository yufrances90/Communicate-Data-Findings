# %% [markdown]
# # (Dataset Exploration Title)
# ## by (your name here)
#
# ## Preliminary Wrangling
#
# > Briefly introduce your dataset here.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %matplotlib inline

# %%
data_dir = './data'

data_file = os.path.join(data_dir, 'austin_data.csv')

df = pd.read_csv(data_file, index_col=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 9999
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   bikeid                          10000 non-null  int64
#  1   checkout_time                   10000 non-null  object
#  2   duration_minutes                10000 non-null  int64
#  3   end_station_id                  10000 non-null  int64
#  4   end_station_name                10000 non-null  object
#  5   month                           10000 non-null  int64
#  6   start_station_id                10000 non-null  int64
#  7   start_station_name              10000 non-null  object
#  8   start_time                      10000 non-null  object
#  9   subscriber_type                 10000 non-null  object
#  10  trip_id                         10000 non-null  int64
#  11  year                            10000 non-null  int64
#  12  date                            10000 non-null  object
#  13  temp_high_F                     10000 non-null  int64
#  14  temp_avg_F                      10000 non-null  int64
#  15  temp_low_F                      10000 non-null  int64
#  16  dew_point_high_F                10000 non-null  object
#  17  dew_point_avg_F                 10000 non-null  object
#  18  dew_point_low_F                 10000 non-null  object
#  19  humidity_high_percent           10000 non-null  object
#  20  humidity_avg_percent            10000 non-null  object
#  21  humidity_low_percent            10000 non-null  object
#  22  sea_level_pressure_high_inches  10000 non-null  object
#  23  sea_level_pressure_avg_inches   10000 non-null  object
#  24  sea_level_pressure_low_inches   10000 non-null  object
#  25  visiblility_high_miles          10000 non-null  object
#  26  visiblility_avg_miles           10000 non-null  object
#  27  visiblility_low_miles           10000 non-null  object
#  28  wind_high_MPH                   10000 non-null  object
#  29  wind_avg_MPH                    10000 non-null  object
#  30  wind_low_MPH                    10000 non-null  object
#  31  precipitaion_sum_inches         10000 non-null  object
#  32  events                          10000 non-null  object
# dtypes: int64(10), object(23)
# memory usage: 2.6+ MB

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### What is the structure of your dataset?
#
# > Your answer here!
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# > Your answer here!
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# > Your answer here!

# %% [markdown]
# ## Univariate Exploration

# %%
sns.countplot(x="year", data=df, color='c')

# %%
df['main_subsciber_type'] = df['subscriber_type'].str.split('(').str[0].str.strip()

# %%
plt.rcParams['figure.figsize'] = (21, 21)
sns.countplot(y="main_subsciber_type", data=df, color='c')

# plt.xscale('log')

# %% [markdown]
# > Make sure that, after every plot or related series of plots, that you
# include a Markdown cell with comments about what you observed, and what
# you plan on investigating next.

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# > Your answer here!
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# > Your answer here!

# %% [markdown]
# ## Bivariate Exploration
#
# > In this section, investigate relationships between pairs of variables in your
# data. Make sure the variables that you cover here have been introduced in some
# fashion in the previous section (univariate exploration).

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# > Your answer here!
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > Your answer here!

# %% [markdown]
# ## Multivariate Exploration
#
# > Create plots of three or more variables to investigate your data even
# further. Make sure that your investigations are justified, and follow from
# your work in the previous sections.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > Your answer here!
#
# ### Were there any interesting or surprising interactions between features?
#
# > Your answer here!

# %% [markdown]
# > At the end of your report, make sure that you export the notebook as an
# html file from the `File > Download as... > HTML` menu. Make sure you keep
# track of where the exported file goes, so you can put it in the same folder
# as this notebook for project submission. Also, make sure you remove all of
# the quote-formatted guide notes like this one before you finish your report!
